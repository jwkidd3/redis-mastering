# %% [markdown]
# # Mastering Redis - Complete 3-Day Course Notebook
#
# ## 📚 Course Overview
#
# **Duration:** 3 Days Intensive (21 hours total)
# **Schedule:** 9:00 AM - 4:00 PM daily with 1-hour lunch break
# **Format:** 70% Hands-on Labs (15 labs), 30% Theory (9 presentations)
# **Platform:** Docker + JavaScript/Node.js + Redis Insight + Visual Studio Code
# **Target:** Insurance Industry Software Engineers, DevOps Engineers, Data Engineers
# **Industry Focus:** Insurance applications, claims processing, policy management
#
# ### 🎉 100% Cross-Platform Support
# All 57 lab scripts are available for **both Mac/Linux AND Windows**!
# - **Mac/Linux:** Bash scripts in `scripts/mac/`
# - **Windows:** PowerShell scripts in `scripts/win/`
# - **Coverage:** 100% (57 scripts per platform)
#
# ### 🎯 Learning Objectives
#
# By the end of this course, participants will be able to:
#
# 1. **Master Redis fundamentals** - architecture, data structures, and operations
# 2. **Build production applications** - customer portals, claims processing, policy management with event sourcing
# 3. **Deploy Redis in production** - security, persistence, monitoring, and scaling
# 4. **Implement event-driven architecture** - Redis Streams for real-time processing
# 5. **Integrate with microservices** - distributed caching and modern patterns
#
# ### 📋 Course Structure
#
# - **Day 1:** Redis CLI & Core Operations (5 labs) - **NO JavaScript**
# - **Day 2:** JavaScript Integration & Event-Driven Architecture (5 labs)
# - **Day 3:** Production Deployment & High Availability (5 labs)
#
# ### ✅ Testing Achievement
# - **Total Tests:** 179 comprehensive tests
# - **Pass Rate:** 100% ✅
# - **Coverage:** All student operations across all 15 labs
#
# ---

# %% [markdown]
# ## 🔧 Environment Setup
#
# ### Prerequisites
#
# Before starting the labs, ensure you have the following installed:
#
# #### Required Software
# - **Docker Desktop** - Container platform for Redis
#   - Windows: Requires Windows 10/11 Pro/Enterprise with WSL 2
#   - Mac: macOS 10.15+ (Catalina or later)
#   - Linux: Ubuntu 18.04+, CentOS 7+
# - **Node.js 18+** - JavaScript runtime (for Day 2-3 labs)
# - **npm** - Node package manager (included with Node.js)
# - **Redis CLI** - Command-line interface tools
# - **Terminal** - Bash (Mac/Linux) or PowerShell (Windows)
#
# #### Optional but Recommended
# - **Visual Studio Code** - Development environment
# - **Redis Insight** - Redis GUI tool
# - **Windows Terminal** - Modern terminal (Windows only)
#
# ### Platform-Specific Setup
#
# #### Windows Users
# ```powershell
# # Enable PowerShell script execution (one-time setup)
# Set-ExecutionPolicy -ExecutionPolicy RemoteSigned -Scope CurrentUser
#
# # Install Redis CLI (via Chocolatey)
# choco install redis
#
# # Or use Redis CLI from Docker
# docker exec redis-course redis-cli
# ```
#
# #### Mac Users
# ```bash
# # Install Redis CLI (via Homebrew)
# brew install redis
# ```
#
# #### Linux Users
# ```bash
# # Install Redis CLI (Ubuntu/Debian)
# sudo apt-get install redis-tools
# ```
#
# ### Quick Setup Verification

# %%
# Environment Setup Verification
import subprocess
import sys

def check_command(command, name):
    try:
        result = subprocess.run([command, '--version'], 
                              capture_output=True, text=True, check=True)
        print(f"✅ {name}: Available")
        return True
    except (subprocess.CalledProcessError, FileNotFoundError):
        print(f"❌ {name}: Not found - Please install before proceeding")
        return False

print("🔍 Checking Prerequisites...")
print("=" * 30)

# Check required tools
check_command('docker', 'Docker')
check_command('node', 'Node.js')
check_command('npm', 'npm')

print("\n📝 Manual Installation Required:")
print("- Redis Insight: https://redis.io/insight/")
print("- Visual Studio Code: https://code.visualstudio.com/")
print("\n🚀 Ready to start the Redis journey!")

# %% [markdown]
# # Day 1: Redis CLI & Core Operations
#
# **Focus:** Pure Redis fundamentals using CLI and Redis Insight (**NO JAVASCRIPT**)
# **Learning Objective:** Master Redis CLI, RESP protocol, and core data operations for insurance systems
#
# ## Labs Overview
#
# 1. **Lab 1:** Redis Environment & CLI Setup (45 min)
# 2. **Lab 2:** RESP Protocol Analysis (45 min)
# 3. **Lab 3:** String Operations & Insurance Data (45 min)
# 4. **Lab 4:** Key Management & TTL Strategies (45 min)
# 5. **Lab 5:** Advanced CLI & Production Monitoring (45 min)
#
# ## Cross-Platform Script Support
#
# All Day 1 labs include scripts for both platforms:
#
# **Mac/Linux:**
# ```bash
# bash scripts/mac/setup-lab.sh
# bash scripts/mac/load-sample-data.sh
# bash scripts/mac/monitor-performance.sh
# ```
#
# **Windows (PowerShell):**
# ```powershell
# .\scripts\win\setup-lab.ps1
# .\scripts\win\load-sample-data.ps1
# .\scripts\win\monitor-performance.ps1
# ```
#
# ---

# %% [markdown]
# ## Lab 1: Redis Environment & CLI for Insurance Systems
#
# **Duration:** 45 minutes
# **Objective:** Set up Redis development environment and master basic CLI operations
#
# ### 🎯 Learning Objectives
# - Install and configure Redis with Docker
# - Master Redis CLI fundamentals
# - Use Redis Insight for data visualization
# - Perform basic insurance data operations
#
# ### Part 1: Environment Setup (15 minutes)

# %%
# Lab 1: Redis Environment Setup Commands
print("🚀 Lab 1: Redis Environment & CLI Setup")
print("=" * 45)

# Docker commands for Redis setup
docker_commands = [
    "# Start Redis container",
    "docker run -d --name redis-course -p 6379:6379 redis:latest",
    "",
    "# Verify Redis is running", 
    "docker ps | grep redis-course",
    "",
    "# Test basic connectivity",
    "redis-cli ping",
    "",
    "# Connect to Redis CLI",
    "redis-cli",
    "",
    "# Or via Docker exec",
    "docker exec -it redis-course redis-cli"
]

print("\n📋 Docker Setup Commands:")
for cmd in docker_commands:
    if cmd.startswith('#'):
        print(f"\n{cmd}")
    elif cmd:
        print(f"  {cmd}")

# Cross-platform lab script commands
print("\n\n🔧 Lab Setup Scripts (Cross-Platform):")
print("=" * 45)

print("\n**Mac/Linux:**")
mac_commands = [
    "cd lab1-redis-cli-basics",
    "bash scripts/mac/setup-lab.sh",
    "bash scripts/mac/test-lab.sh"
]
for cmd in mac_commands:
    print(f"  {cmd}")

print("\n**Windows (PowerShell):**")
win_commands = [
    "cd lab1-redis-cli-basics",
    ".\\scripts\\win\\setup-lab.ps1",
    ".\\scripts\\win\\test-lab.ps1"
]
for cmd in win_commands:
    print(f"  {cmd}")

print("\n✅ All 57 lab scripts available for both Mac/Linux and Windows")
print("🔍 Use Redis Insight to connect to localhost:6379")

# %%
# Lab 1: Basic CLI Operations for Insurance Data
redis_commands = [
    "# Basic connectivity test",
    "PING",
    "",
    "# Server information",
    "INFO server",
    "INFO memory",
    "",
    "# Basic string operations for insurance data",
    "SET customer:001 'John Smith'",
    "GET customer:001", 
    "SET policy:auto:001 'Auto Policy - Premium $1200'",
    "GET policy:auto:001",
    "",
    "# Insurance agent data",
    "SET agent:001 'Sarah Johnson - Auto Specialist'",
    "SET claim:001 'Auto Claim - Accident on Highway 101'",
    "",
    "# Check all keys",
    "KEYS *",
    "",
    "# Database statistics", 
    "DBSIZE",
    "",
    "# Help system",
    "HELP SET",
    "HELP GET"
]

print("📋 Redis CLI Commands for Lab 1:")
print("=" * 35)

for cmd in redis_commands:
    if cmd.startswith('#'):
        print(f"\n{cmd}")
    elif cmd:
        print(f"  redis-cli> {cmd}")
        
print("\n💡 Execute these commands in Redis CLI to practice")
print("🔍 Use Redis Insight to visualize the data you create")

# %% [markdown]
# # Day 2: JavaScript Integration & Event-Driven Architecture
#
# **Focus:** JavaScript/Node.js Redis client integration with modern event-driven patterns
# **Learning Objective:** Build production insurance applications with event sourcing
#
# ## Labs Overview
#
# 1. **Lab 6:** JavaScript Redis Client Setup (45 min)
# 2. **Lab 7:** Customer Profiles with Hashes (45 min)
# 3. **🌟 Lab 8:** Claims Event Sourcing with Redis Streams (45 min) **FEATURED**
# 4. **Lab 9:** Insurance Analytics with Sets & Sorted Sets (45 min)
# 5. **Lab 10:** Advanced Caching Patterns (45 min)
#
# ## 🌟 Featured Lab: Lab 8 - Claims Event Sourcing
#
# **Modern Event-Driven Architecture with Redis Streams**
#
# Lab 8 showcases cutting-edge event sourcing patterns:
# - **Producer/Consumer Groups:** Distributed event processing
# - **Immutable Audit Trails:** Complete claims history for compliance
# - **Real-time Analytics:** Stream-powered dashboards
# - **Event Replay:** Rebuild state from event history
#
# ### Key npm Scripts:
# ```bash
# cd lab8-claims-event-sourcing
# npm install
# npm run validate          # Validate setup
# npm run load-data         # Load sample claims
# npm run producer          # Submit claims (Terminal 1)
# npm run consumer          # Process events (Terminal 2)
# npm run analytics         # View analytics (Terminal 3)
# npm test                  # Run comprehensive tests
# ```
#
# ### Event Types:
# - `claim.submitted` - Initial claim creation
# - `claim.assigned` - Assigned to adjuster
# - `claim.document.uploaded` - Supporting docs
# - `claim.investigated` - Investigation activities
# - `claim.approved` - Approval decision
# - `claim.payment.completed` - Settlement
#
# ### Cross-Platform Setup:
# **Mac/Linux:**
# ```bash
# bash scripts/mac/setup-lab.sh
# ```
#
# **Windows (PowerShell):**
# ```powershell
# .\scripts\win\setup-lab.ps1
# ```
#
# ---

# %%
# Lab 6: JavaScript Redis Client Project Setup
print("🚀 Lab 6: JavaScript Redis Client Setup")
print("=" * 45)

# Project structure
project_structure = '''
lab6-javascript-redis-client/
├── package.json                 # Node.js dependencies
├── .env                        # Environment variables  
├── src/
│   ├── config/redis.js         # Redis configuration
│   ├── clients/redisClient.js  # Redis client wrapper
│   ├── models/
│   │   ├── customer.js         # Customer operations
│   │   └── policy.js           # Policy operations
│   └── app.js                  # Main application
├── examples/
│   ├── basic-operations.js     # Basic Redis operations
│   └── performance-test.js     # Performance testing
└── tests/
    └── connection-test.js      # Connection testing
'''

print("📁 Project Structure:")
print(project_structure)

# Package.json content
package_json = {
    "name": "redis-insurance-client",
    "version": "1.0.0", 
    "description": "Insurance system Redis client",
    "main": "src/app.js",
    "scripts": {
        "start": "node src/app.js",
        "test": "node tests/connection-test.js",
        "dev": "nodemon src/app.js",
        "examples": "node examples/basic-operations.js"
    },
    "dependencies": {
        "redis": "^4.6.0",
        "dotenv": "^16.3.0"
    },
    "devDependencies": {
        "nodemon": "^3.0.0"
    }
}

print("\n📦 Package.json Dependencies:")
import json
print(json.dumps(package_json, indent=2))

# %%
# Lab 6: JavaScript Redis Client Code Examples

# Redis Configuration (src/config/redis.js)
redis_config_js = """
require('dotenv').config();

const redisConfig = {
    socket: {
        host: process.env.REDIS_HOST || 'localhost',
        port: parseInt(process.env.REDIS_PORT) || 6379,
        connectTimeout: 10000,
        lazyConnect: true
    },
    password: process.env.REDIS_PASSWORD,
    database: parseInt(process.env.REDIS_DB) || 0,
    retryDelayOnFailover: 100,
    maxRetriesPerRequest: 3
};

module.exports = redisConfig;
"""

# Redis Client Wrapper (src/clients/redisClient.js)  
redis_client_js = """
const redis = require('redis');
const config = require('../config/redis');

class RedisClient {
    constructor() {
        this.client = null;
        this.isConnected = false;
    }

    async connect() {
        try {
            this.client = redis.createClient(config);
            
            this.client.on('error', (err) => {
                console.error('Redis error:', err.message);
                this.isConnected = false;
            });

            this.client.on('ready', () => {
                console.log('✅ Redis client ready');
                this.isConnected = true;
            });

            await this.client.connect();
            return this.client;
            
        } catch (error) {
            console.error('❌ Redis connection failed:', error.message);
            throw error;
        }
    }

    async disconnect() {
        if (this.client) {
            await this.client.disconnect();
        }
    }

    getClient() {
        return this.client;
    }

    isReady() {
        return this.isConnected;
    }
}

module.exports = RedisClient;
"""

print("📝 JavaScript Code Files:")
print("=" * 25)
print("\n🔧 Redis Configuration:")
print(redis_config_js)
print("\n🔌 Redis Client Wrapper:")  
print(redis_client_js)

# %% [markdown]
# # Day 3: Production Deployment & High Availability
#
# **Focus:** Enterprise deployment patterns, monitoring, and Redis Cluster
# **Learning Objective:** Deploy production-ready Redis systems with high availability
#
# ## Labs Overview
#
# 1. **Lab 11:** Session Management & Security (45 min)
# 2. **Lab 12:** Rate Limiting & API Protection (45 min)
# 3. **Lab 13:** Production Configuration (45 min)
# 4. **Lab 14:** Production Monitoring & Health Checks (45 min)
# 5. **🌟 Lab 15:** Redis Cluster & High Availability (45 min) **FEATURED**
#
# ## 🌟 Featured Lab: Lab 15 - Redis Cluster HA
#
# **Production-Grade 6-Node Redis Cluster**
#
# Lab 15 implements enterprise-grade high availability:
# - **6-Node Cluster:** 3 masters + 3 replicas
# - **Automatic Sharding:** 16,384 hash slots distributed
# - **Automatic Failover:** Master failure detection and promotion
# - **Cluster Management:** Add/remove nodes, rebalance slots
#
# ### Architecture:
# ```
# Master-1 (Port 9000, Slots 0-5461)      Master-2 (Port 9001, Slots 5462-10922)      Master-3 (Port 9002, Slots 10923-16383)
#     ↓                                        ↓                                            ↓
# Replica-1 (Port 9003)                   Replica-2 (Port 9004)                       Replica-3 (Port 9005)
# ```
#
# ### Key npm Scripts:
# ```bash
# cd lab15-redis-cluster-ha
# npm install
# docker-compose up -d      # Start 6-node cluster
# npm run test-sharding     # Test data distribution
# npm run load-data         # Load insurance data
# npm run monitor           # Cluster monitoring
# npm run chaos-test        # Test failover
# ```
#
# ### Cluster Management Scripts:
#
# **Mac/Linux:**
# ```bash
# bash scripts/mac/init-cluster.sh         # Initialize cluster
# bash scripts/mac/show-slot-distribution.sh  # View slots
# bash scripts/mac/manual-failover.sh      # Test failover
# bash scripts/mac/add-master-node.sh      # Scale up
# ```
#
# **Windows (PowerShell):**
# ```powershell
# .\scripts\win\init-cluster.ps1           # Initialize cluster
# .\scripts\win\show-slot-distribution.ps1 # View slots
# .\scripts\win\manual-failover.ps1        # Test failover
# .\scripts\win\add-master-node.ps1        # Scale up
# ```
#
# ---

# %%
# Lab 13: Production Redis Configuration
print("🚀 Lab 13: Production Configuration")
print("=" * 40)

# Production Redis configuration
redis_prod_conf = '''
# Redis Production Configuration for Insurance Systems
# Network Configuration
bind 0.0.0.0
port 6379
protected-mode yes
timeout 300

# Security Configuration  
requirepass your_strong_password_here
rename-command FLUSHDB ""
rename-command FLUSHALL ""

# Memory Management
maxmemory 2gb
maxmemory-policy allkeys-lru

# Persistence Configuration
save 900 1
save 300 10
save 60 10000
appendonly yes
appendfilename "insurance-appendonly.aof"

# Logging
loglevel notice
logfile /var/log/redis/redis-server.log

# Performance Tuning
slowlog-log-slower-than 10000
slowlog-max-len 128
'''

print("📄 Production Redis Configuration:")
print(redis_prod_conf)

# Docker Compose
docker_compose = '''
version: '3.8'

services:
  redis-insurance:
    image: redis:7-alpine
    container_name: redis-insurance-prod
    restart: unless-stopped
    ports:
      - "6379:6379"
    volumes:
      - ./config/redis.conf:/usr/local/etc/redis/redis.conf:ro
      - redis-data:/data
    command: redis-server /usr/local/etc/redis/redis.conf
    healthcheck:
      test: ["CMD", "redis-cli", "ping"]
      interval: 30s
      timeout: 10s
      retries: 3

volumes:
  redis-data:
    driver: local
'''

print("\n🐳 Production Docker Compose:")
print(docker_compose)

# %% [markdown]
# ## 📊 Redis Monitoring & Performance
#
# ### Key Metrics to Monitor
#
# 1. **Memory Usage** - Used memory, peak memory, fragmentation ratio
# 2. **Connection Count** - Active clients, rejected connections
# 3. **Operations per Second** - Commands processed, throughput
# 4. **Cache Hit Ratio** - Keyspace hits vs misses
# 5. **Slow Queries** - Operations taking longer than threshold
# 6. **Persistence Performance** - RDB save time, AOF rewrite time

# %%
# Redis Monitoring Commands and Testing Framework
print("📊 Redis Monitoring & Comprehensive Testing")
print("=" * 50)

# Essential monitoring commands
monitoring_commands = [
    "# Memory information",
    "INFO memory",
    "",
    "# Performance statistics", 
    "INFO stats",
    "",
    "# Connection information",
    "INFO clients",
    "", 
    "# Slow log analysis",
    "SLOWLOG GET 10",
    "SLOWLOG LEN",
    "",
    "# Key analysis",
    "DBSIZE",
    "MEMORY USAGE keyname"
]

print("🔍 Monitoring Commands:")
for cmd in monitoring_commands:
    if cmd.startswith('#'):
        print(f"\n{cmd}")
    elif cmd:
        print(f"  redis-cli> {cmd}")

# Test Suite Information
print("\n\n✅ Comprehensive Test Suite")
print("=" * 35)

test_info = {
    "Total Tests": "179 tests",
    "Pass Rate": "100% ✅",
    "Coverage": "All student operations across 15 labs",
    "Test Types": "Integration, functional, and scenario-based",
    "Execution Time": "~0.11 seconds"
}

print("\n📊 Test Statistics:")
for key, value in test_info.items():
    print(f"  {key}: {value}")

print("\n🧪 Running Tests:")
test_commands = {
    "All Tests": "npm test",
    "Day 1 Tests": "npm run test:day1  # CLI & Core Operations",
    "Day 2 Tests": "npm run test:day2  # JavaScript Integration",
    "Day 3 Tests": "npm run test:day3  # Production & Advanced"
}

for name, cmd in test_commands.items():
    print(f"  {name:15s} {cmd}")

print("\n💡 Tests validate:")
print("  • All Redis CLI operations from Day 1")
print("  • All JavaScript client operations from Day 2-3")
print("  • Event sourcing with Streams (Lab 8)")
print("  • Session management (Lab 11)")
print("  • Rate limiting algorithms (Lab 12)")
print("  • Production configuration (Lab 13)")

# Python monitoring script
monitoring_script = '''
import redis
import time
import json
from datetime import datetime

class RedisMonitor:
    def __init__(self, host='localhost', port=6379, password=None):
        self.r = redis.Redis(host=host, port=port, password=password, decode_responses=True)
        
    def get_memory_info(self):
        info = self.r.info('memory')
        return {
            'used_memory_human': info.get('used_memory_human'),
            'used_memory_peak_human': info.get('used_memory_peak_human'),
            'mem_fragmentation_ratio': info.get('mem_fragmentation_ratio')
        }
    
    def get_performance_stats(self):
        info = self.r.info('stats')
        return {
            'total_commands_processed': info.get('total_commands_processed'),
            'instantaneous_ops_per_sec': info.get('instantaneous_ops_per_sec'),
            'keyspace_hits': info.get('keyspace_hits'),
            'keyspace_misses': info.get('keyspace_misses'),
            'connected_clients': info.get('connected_clients')
        }
    
    def calculate_hit_ratio(self):
        stats = self.get_performance_stats()
        hits = stats['keyspace_hits']
        misses = stats['keyspace_misses']
        total = hits + misses
        return (hits / total * 100) if total > 0 else 0
    
    def monitor_report(self):
        timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        memory = self.get_memory_info()
        stats = self.get_performance_stats()
        hit_ratio = self.calculate_hit_ratio()
        
        report = {
            'timestamp': timestamp,
            'memory': memory,
            'performance': stats,
            'cache_hit_ratio': f"{hit_ratio:.2f}%"
        }
        
        print(f"\\n[{timestamp}] Redis Health Report:")
        print(json.dumps(report, indent=2))

# Usage:
# monitor = RedisMonitor(host='your-redis-host', password='your-password')
# monitor.monitor_report()
'''

print("\n\n🐍 Python Monitoring Script:")
print(monitoring_script)

# %% [markdown]
# ## 🎯 Redis Best Practices & Troubleshooting
#
# ### 🏆 Production Best Practices
#
# #### 1. **Key Design**
# - Use consistent naming conventions: `domain:type:id`
# - Avoid very long key names (memory overhead)
# - Use appropriate data types for your use case
#
# #### 2. **Memory Management**
# - Set `maxmemory` and appropriate eviction policy
# - Monitor memory usage regularly
# - Use Redis data type memory optimizations
#
# #### 3. **Security**
# - Always use authentication (`requirepass`)
# - Disable dangerous commands (`FLUSHALL`, `CONFIG`)
# - Use network security (VPC, firewalls)
# - Enable SSL/TLS for data in transit
#
# #### 4. **Performance**
# - Use pipelining for bulk operations
# - Avoid blocking operations in production
# - Monitor slow queries with `SLOWLOG`
# - Use appropriate data structures

# %%
# Redis Troubleshooting Guide
print("🐛 Redis Troubleshooting Guide")
print("=" * 30)

troubleshooting_scenarios = {
    "High Memory Usage": {
        "symptoms": [
            "Redis using more memory than expected",
            "Memory fragmentation ratio > 1.5",
            "Out of memory errors"
        ],
        "solutions": [
            "Set maxmemory and eviction policy",
            "Optimize data structures",
            "Remove unused keys",
            "Consider clustering for scale"
        ]
    },
    "Slow Performance": {
        "symptoms": [
            "High response times",
            "Low operations per second",
            "Client timeouts"
        ],
        "solutions": [
            "Optimize slow queries",
            "Use pipelining for bulk operations", 
            "Check network latency",
            "Tune kernel parameters"
        ]
    },
    "Connection Issues": {
        "symptoms": [
            "Connection refused errors",
            "Too many clients",
            "Authentication failures"
        ],
        "solutions": [
            "Increase maxclients setting",
            "Implement connection pooling",
            "Check firewall settings",
            "Verify authentication"
        ]
    }
}

for issue, details in troubleshooting_scenarios.items():
    print(f"\n🔍 Issue: {issue}")
    print("-" * (len(issue) + 10))
    
    print("\n📋 Symptoms:")
    for symptom in details["symptoms"]:
        print(f"  • {symptom}")
    
    print("\n💡 Solutions:")
    for solution in details["solutions"]:
        print(f"  • {solution}")

# Performance optimization checklist
performance_checklist = [
    "✅ Set appropriate maxmemory and eviction policy",
    "✅ Use Redis data structure memory optimizations", 
    "✅ Implement connection pooling in applications",
    "✅ Use pipelining for bulk operations",
    "✅ Monitor and optimize slow queries",
    "✅ Configure appropriate persistence settings",
    "✅ Set up monitoring and alerting",
    "✅ Use clustering for horizontal scaling",
    "✅ Optimize network configuration",
    "✅ Regular backup and disaster recovery testing"
]

print("\n\n🚀 Performance Optimization Checklist:")
print("=" * 40)
for item in performance_checklist:
    print(f"  {item}")

# %% [markdown]
# ## 🎓 Course Summary & Achievements
#
# ### 🏆 Congratulations!
#
# You have successfully completed the **Mastering Redis - 3-Day Intensive Course**!
#
# ### 🎉 Major Course Achievements
#
# #### ✅ 100% Cross-Platform Script Coverage
# - **Mac/Linux:** 57 bash scripts (`.sh`) in `scripts/mac/`
# - **Windows:** 57 PowerShell scripts (`.ps1`) in `scripts/win/`
# - **Coverage:** 100% - Every lab script available on every platform
# - **No Workarounds:** Native scripts for Windows users (no WSL/Git Bash required)
#
# #### ✅ Comprehensive Testing Framework
# - **Total Tests:** 179 comprehensive tests
# - **Pass Rate:** 100% ✅
# - **Coverage:** All student operations across all 15 labs
# - **Test Types:** Integration, functional, scenario-based
# - **Execution:** Fast (~0.11 seconds) and reliable
#
# #### ✅ Modern Event-Driven Architecture
# - **Lab 8:** Claims Event Sourcing with Redis Streams
# - **Producer/Consumer:** Distributed event processing patterns
# - **Audit Trails:** Immutable event logs for compliance
# - **Real-time Analytics:** Stream-powered dashboards
#
# #### ✅ Production-Grade High Availability
# - **Lab 15:** 6-Node Redis Cluster implementation
# - **Automatic Sharding:** 16,384 hash slots distributed
# - **Automatic Failover:** Master failure detection and promotion
# - **Cluster Management:** Full suite of management tools
#
# ### 📚 What You've Learned
#
# #### **Day 1: Redis Fundamentals (CLI-Only)**
# - ✅ Redis installation and configuration with Docker
# - ✅ Redis CLI mastery and RESP protocol understanding
# - ✅ String operations for insurance data (policies, customers, claims)
# - ✅ Key management strategies and TTL patterns
# - ✅ Advanced CLI operations and production monitoring
#
# #### **Day 2: JavaScript Integration & Event-Driven Architecture**
# - ✅ Node.js Redis client setup and connection pooling
# - ✅ Customer and policy management with hashes
# - ✅ **Claims event sourcing with Redis Streams** (Featured)
# - ✅ Insurance analytics with sets and sorted sets
# - ✅ Advanced caching patterns (cache-aside, write-through, event-driven invalidation)
#
# #### **Day 3: Production Deployment & High Availability**
# - ✅ Session management with JWT and RBAC
# - ✅ Rate limiting and API protection (token bucket, sliding window)
# - ✅ Production configuration (RDB/AOF persistence, backups)
# - ✅ Monitoring, alerting, and health checks
# - ✅ **Redis Cluster with high availability** (Featured)
#
# ### 🚀 Next Steps
#
# #### **Immediate Actions**
# 1. **Practice** - Set up Redis in your development environment
# 2. **Experiment** - Try Redis with your existing applications
# 3. **Monitor** - Implement basic monitoring for any Redis instances
# 4. **Secure** - Apply security best practices learned
# 5. **Test** - Run the comprehensive test suite: `npm test`
#
# #### **Advanced Learning**
# 1. **Redis Modules** - Explore RedisJSON, RedisSearch, RedisTimeSeries
# 2. **Redis Cluster** - Master advanced clustering and sharding
# 3. **Redis Streams** - Deep dive into event streaming patterns
# 4. **Redis Enterprise** - Explore enterprise features and support
# 5. **Contribute** - Join the Redis open source community
#
# ### 📖 Documentation & Resources
#
# #### Course Documentation
# - **README.md** - Comprehensive consolidated guide (all-in-one)
# - **CROSS-PLATFORM-SCRIPTS-COMPLETE.md** - Complete script documentation
# - **Lab READMEs** - Detailed instructions in each of 15 lab directories
# - **Presentations** - 9 Reveal.js HTML presentations
#
# #### Official Resources
# - **Redis Documentation:** https://redis.io/documentation
# - **Redis University:** https://university.redis.io/
# - **Redis Commands:** https://redis.io/commands/
# - **Redis Community:** https://redis.io/community/
# - **Node Redis Client:** https://github.com/redis/node-redis
#
# #### Tools Used
# - **Docker Desktop** - Container platform
# - **Node.js 18+** - JavaScript runtime
# - **Redis Insight** - GUI tool for Redis
# - **Visual Studio Code** - Development environment
# - **Redis CLI** - Command-line interface
#
# ### 🎯 Course Statistics
#
# - **Total Duration:** 21 hours over 3 days
# - **Hands-on Labs:** 15 labs × 45 minutes = 11.25 hours (70%)
# - **Theory Sessions:** 9 presentations = 6.25 hours (30%)
# - **Scripts Created:** 57 Mac/Linux + 57 Windows = 114 total scripts
# - **Code Examples:** 3000+ lines across all labs
# - **Test Coverage:** 179 comprehensive tests at 100% pass rate
# - **Technologies:** Redis 7+, JavaScript/Node.js, Docker, PowerShell, Bash
# - **Industry Focus:** Insurance applications (claims, policies, customers, analytics)
#
# ### 🌟 Featured Highlights
#
# **Lab 8: Claims Event Sourcing**
# - Modern event-driven architecture
# - Redis Streams for audit trails
# - Producer/consumer groups
# - Real-time analytics dashboard
#
# **Lab 15: Redis Cluster HA**
# - 6-node production cluster
# - Automatic sharding and failover
# - Complete cluster management tools
# - Enterprise-grade high availability
#
# ### 💪 Skills Mastered
#
# You can now:
# - ✅ Deploy Redis in production environments
# - ✅ Build scalable insurance applications with event sourcing
# - ✅ Implement advanced caching strategies
# - ✅ Monitor and optimize Redis performance
# - ✅ Integrate Redis with microservices
# - ✅ Troubleshoot Redis issues effectively
# - ✅ Apply Redis security best practices
# - ✅ Design efficient data models
# - ✅ Implement high availability with clustering
# - ✅ Write cross-platform deployment scripts
#
# ---
#
# ### 💫 Thank You!
#
# Thank you for completing the **Mastering Redis** course. You now have the knowledge and skills to:
# - Implement Redis solutions in production
# - Build event-driven architectures
# - Deploy high-availability clusters
# - Optimize performance at scale
#
# **Keep coding, keep learning, and keep building amazing things with Redis!** 🚀
#
# ### 🎓 Course Completion Checklist
#
# - [ ] Completed all 15 labs (Day 1-3)
# - [ ] Passed all 179 comprehensive tests
# - [ ] Reviewed all 9 presentations
# - [ ] Built sample insurance application
# - [ ] Deployed Redis in production configuration
# - [ ] Implemented monitoring and alerting
# - [ ] Practiced backup and recovery
# - [ ] Tested cluster failover scenarios
# - [ ] Understood event sourcing patterns
# - [ ] Ready for production Redis deployment

# %%
# Course Completion Summary with All Achievements
print("🎉 Redis Mastering Course - Final Summary")
print("=" * 50)

# Major achievements
achievements = {
    "Cross-Platform Scripts": {
        "Mac/Linux Scripts": "57 bash scripts (.sh)",
        "Windows Scripts": "57 PowerShell scripts (.ps1)",
        "Coverage": "100% - Every script available on every platform",
        "Organization": "scripts/mac/ and scripts/win/ directories"
    },
    "Testing Framework": {
        "Total Tests": "179 comprehensive tests",
        "Pass Rate": "100% ✅",
        "Coverage": "All student operations across 15 labs",
        "Execution Time": "~0.11 seconds"
    },
    "Featured Labs": {
        "Lab 8": "Claims Event Sourcing with Redis Streams",
        "Lab 15": "6-Node Redis Cluster with High Availability"
    }
}

print("\n🏆 Major Course Achievements:")
print("=" * 50)
for category, details in achievements.items():
    print(f"\n✅ {category}:")
    for key, value in details.items():
        print(f"   • {key}: {value}")

# Course statistics
course_stats = {
    "Total Duration": "21 hours (3 days)",
    "Hands-on Labs": "15 labs × 45 minutes = 11.25 hours (70%)",
    "Theory Sessions": "9 presentations = 6.25 hours (30%)",
    "Total Scripts": "114 scripts (57 Mac + 57 Windows)",
    "Technologies": "Redis 7+, JavaScript, Node.js, Docker, PowerShell, Bash",
    "Industry Focus": "Insurance applications and business processes",
    "Code Examples": "3000+ lines across all labs",
    "Test Coverage": "179 tests at 100% pass rate"
}

print("\n\n📊 Complete Course Statistics:")
print("=" * 50)
for key, value in course_stats.items():
    print(f"  {key}: {value}")

# Skills mastered by day
skills_by_day = {
    "Day 1 - CLI Fundamentals": [
        "Redis CLI operations and RESP protocol",
        "String operations for insurance data",
        "Key management and TTL strategies",
        "Advanced monitoring and performance analysis"
    ],
    "Day 2 - JavaScript & Event-Driven": [
        "Node.js Redis client development",
        "Hash operations for customer/policy management",
        "Event sourcing with Redis Streams (Featured)",
        "Sets/sorted sets for analytics",
        "Advanced caching patterns"
    ],
    "Day 3 - Production & HA": [
        "Session management with JWT and RBAC",
        "Rate limiting and API protection",
        "Production configuration (RDB/AOF, backups)",
        "Monitoring, alerting, health checks",
        "Redis Cluster with high availability (Featured)"
    ]
}

print("\n\n🎯 Skills Mastered by Day:")
print("=" * 50)
for day, skills in skills_by_day.items():
    print(f"\n{day}:")
    for skill in skills:
        print(f"  ✅ {skill}")

# Platform support details
platform_support = {
    "Mac/Linux": {
        "Scripts": "57 bash scripts in scripts/mac/",
        "Format": ".sh files",
        "Example": "bash scripts/mac/setup-lab.sh"
    },
    "Windows": {
        "Scripts": "57 PowerShell scripts in scripts/win/",
        "Format": ".ps1 files",
        "Example": ".\\scripts\\win\\setup-lab.ps1"
    },
    "Git Bash/WSL": {
        "Scripts": "Can use Mac scripts",
        "Format": ".sh files",
        "Example": "bash scripts/mac/setup-lab.sh"
    }
}

print("\n\n🖥️  Cross-Platform Support Details:")
print("=" * 50)
for platform, details in platform_support.items():
    print(f"\n{platform}:")
    for key, value in details.items():
        print(f"  • {key}: {value}")

# Featured lab highlights
featured_labs = {
    "Lab 8: Claims Event Sourcing": {
        "Technology": "Redis Streams",
        "Pattern": "Event-driven architecture",
        "Features": [
            "Producer/consumer groups",
            "Immutable audit trails",
            "Real-time analytics",
            "Event replay capabilities"
        ],
        "Commands": [
            "npm run producer  # Submit claims",
            "npm run consumer  # Process events",
            "npm run analytics # View dashboard"
        ]
    },
    "Lab 15: Redis Cluster HA": {
        "Technology": "Redis Cluster",
        "Pattern": "High availability with sharding",
        "Features": [
            "6-node cluster (3 masters, 3 replicas)",
            "16,384 hash slots distributed",
            "Automatic failover",
            "Cluster management tools"
        ],
        "Commands": [
            "docker-compose up -d      # Start cluster",
            "npm run test-sharding     # Test distribution",
            "npm run monitor           # Monitor cluster"
        ]
    }
}

print("\n\n🌟 Featured Lab Highlights:")
print("=" * 50)
for lab_name, details in featured_labs.items():
    print(f"\n{lab_name}")
    print(f"  Technology: {details['Technology']}")
    print(f"  Pattern: {details['Pattern']}")
    print(f"  Features:")
    for feature in details['Features']:
        print(f"    • {feature}")
    print(f"  Key Commands:")
    for cmd in details['Commands']:
        print(f"    $ {cmd}")

# Testing achievements
print("\n\n✅ Comprehensive Testing Achievement:")
print("=" * 50)
test_achievements = [
    "179 total tests covering all 15 labs",
    "100% pass rate - all tests passing",
    "All student operations validated",
    "Integration and scenario-based tests",
    "Fast execution (~0.11 seconds)",
    "Tests for CLI operations (Day 1)",
    "Tests for JavaScript operations (Day 2-3)",
    "Tests for event sourcing (Lab 8)",
    "Tests for session management (Lab 11)",
    "Tests for rate limiting (Lab 12)"
]

for achievement in test_achievements:
    print(f"  ✅ {achievement}")

print("\n\n🚀 You Are Now Ready To:")
print("=" * 50)
readiness_items = [
    "Deploy Redis in production environments",
    "Build event-driven insurance applications",
    "Implement advanced caching strategies",
    "Monitor and optimize Redis performance",
    "Integrate Redis with microservices",
    "Troubleshoot Redis issues effectively",
    "Apply Redis security best practices",
    "Design efficient data models",
    "Implement high availability clustering",
    "Write cross-platform deployment scripts"
]

for item in readiness_items:
    print(f"  ✅ {item}")

print("\n\n📚 Documentation Available:")
print("=" * 50)
documentation = [
    "README.md - Comprehensive consolidated guide",
    "CROSS-PLATFORM-SCRIPTS-COMPLETE.md - Script docs",
    "15 lab READMEs - Detailed lab instructions",
    "9 Reveal.js presentations - Theory content",
    "Architecture docs in lab directories",
    "Code examples in examples/ directories"
]

for doc in documentation:
    print(f"  📄 {doc}")

print("\n\n💡 Next Learning Opportunities:")
print("=" * 50)
next_steps = [
    "🎯 Redis University advanced courses",
    "🎯 Redis modules (JSON, Search, TimeSeries)",
    "🎯 Redis Enterprise features",
    "🎯 Advanced Redis Streams patterns",
    "🎯 Redis certification programs",
    "🎯 Contributing to Redis open source"
]

for step in next_steps:
    print(f"  {step}")

print("\n" + "=" * 50)
print("🎓 CONGRATULATIONS on completing Redis Mastering!")
print("=" * 50)
print("\n💪 You now have enterprise-level Redis skills!")
print("🚀 Keep building amazing things with Redis!")
print("🌟 Share your knowledge with the community!")
print("\n" + "=" * 50)
